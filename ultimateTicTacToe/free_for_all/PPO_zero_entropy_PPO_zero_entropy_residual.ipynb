# %%
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
from setproctitle import setproctitle
setproctitle("ppo_zero_entropy_vs_ppo_zero_entropy_residual")

# %%
import sys
sys.path.append('..')

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2025-05-26 16:49:07.710268: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-26 16:49:07.710300: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-26 16:49:07.711385: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-26 16:49:07.717034: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-26 16:49:08.281990: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-05-26 16:49:09.228531: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.269625: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.269918: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from tqdm import trange
from UltimateTicTacToeEnvSelfPlay import UltimateTicTacToeEnvSelfPlay
from A2CAgent import A2CAgent
from PPOAgent import PPOAgent
from PPOAgent_with_improvements import PPOAgent as PPOAgent_with_improvements

# %%
NUM_OF_GAMES = 500
envs = [UltimateTicTacToeEnvSelfPlay() for _ in range(NUM_OF_GAMES)]
state_space_shape = envs[0].to_state()[0].shape[0]
action_space_size = 81
a2c_agent = PPOAgent(state_space_shape, action_space_size, loaded=True, model_path="../models/Thesis_PPO_data_augmentation")
ppo_agent = PPOAgent_with_improvements(state_space_shape, action_space_size, loaded=True, model_path="../models/Thesis_PPO_resnet")
dones = np.zeros((NUM_OF_GAMES,), dtype=bool)
final_rewards = np.zeros((NUM_OF_GAMES,))
while(not np.all(dones) != 0):
    print(np.sum(dones), " out of ", len(dones))
    a2c_states = np.array([env.to_state()[0] for env in envs])
    a2c_available_actions = np.array([env.to_state()[1] for env in envs])
    a2c_actions = a2c_agent.act(a2c_states, a2c_available_actions)
    a2c_reward = np.zeros(NUM_OF_GAMES)
    game_finished = np.zeros(NUM_OF_GAMES)
    for i in range(NUM_OF_GAMES):
        _, a2c_reward[i], game_finished[i], _  = envs[i].step(a2c_actions[i])
        if game_finished[i] == True and dones[i] == False:
            dones[i] = True
            final_rewards[i] = a2c_reward[i]
    
    ppo_states = np.array([env.to_state()[0] for env in envs])
    ppo_available_actions = np.array([env.to_state()[1] for env in envs])
    ppo_actions = ppo_agent.act(ppo_states, ppo_available_actions)
    ppo_reward = np.zeros(NUM_OF_GAMES)
    game_finished = np.zeros(NUM_OF_GAMES)
    for i in range(NUM_OF_GAMES):
            _, ppo_reward[i], game_finished[i], _  = envs[i].step(ppo_actions[i])
            if game_finished[i] == True and dones[i] == False:
                dones[i] = True
                final_rewards[i] = -ppo_reward[i]
    print("Both players have done a move.")

win_as_first_player = np.count_nonzero(final_rewards == 1)/len(dones)
draw_as_first_player = np.count_nonzero(final_rewards == 0)/len(dones)

print("win rate as first player: ", win_as_first_player)
print("draw rate as first player: ", draw_as_first_player)
# Out:
# Models loaded from memory
# 2025-05-26 16:49:09.508185: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.508514: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.508759: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.570149: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.570421: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.570663: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-26 16:49:09.570868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9508 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Models loaded from memory
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 0  out of  500
# 2025-05-26 16:49:11.323470: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 1  out of  500
# Both players have done a move.
# 1  out of  500
# Both players have done a move.
# 2  out of  500
# Both players have done a move.
# 3  out of  500
# Both players have done a move.
# 9  out of  500
# Both players have done a move.
# 22  out of  500
# Both players have done a move.
# 44  out of  500
# Both players have done a move.
# 78  out of  500
# Both players have done a move.
# 122  out of  500
# Both players have done a move.
# 179  out of  500
# Both players have done a move.
# 259  out of  500
# Both players have done a move.
# 331  out of  500
# Both players have done a move.
# 384  out of  500
# Both players have done a move.
# 435  out of  500
# Both players have done a move.
# 466  out of  500
# Both players have done a move.
# 482  out of  500
# Both players have done a move.
# 489  out of  500
# Both players have done a move.
# 496  out of  500
# Both players have done a move.
# 499  out of  500
# Both players have done a move.
# win rate as first player:  0.472
# draw rate as first player:  0.046

# %%
NUM_OF_GAMES = 500
envs = [UltimateTicTacToeEnvSelfPlay() for _ in range(NUM_OF_GAMES)]
state_space_shape = envs[0].to_state()[0].shape[0]
action_space_size = 81
a2c_agent = PPOAgent(state_space_shape, action_space_size, loaded=True, model_path="../models/Thesis_PPO_data_augmentation")
ppo_agent = PPOAgent(state_space_shape, action_space_size, loaded=True, model_path="../models/Thesis_PPO_resnet")
dones = np.zeros((NUM_OF_GAMES,), dtype=bool)
final_rewards = np.zeros((NUM_OF_GAMES,))
while(not np.all(dones) != 0):
    print(np.sum(dones), " out of ", len(dones))
    ppo_states = np.array([env.to_state()[0] for env in envs])
    ppo_available_actions = np.array([env.to_state()[1] for env in envs])
    ppo_actions = ppo_agent.act(ppo_states, ppo_available_actions)
    ppo_reward = np.zeros(NUM_OF_GAMES)
    game_finished = np.zeros(NUM_OF_GAMES)
    for i in range(NUM_OF_GAMES):
            _, ppo_reward[i], game_finished[i], _  = envs[i].step(ppo_actions[i])
            if game_finished[i] == True and dones[i] == False:
                dones[i] = True
                final_rewards[i] = -ppo_reward[i]
                
    a2c_states = np.array([env.to_state()[0] for env in envs])
    a2c_available_actions = np.array([env.to_state()[1] for env in envs])
    a2c_actions = a2c_agent.act(a2c_states, a2c_available_actions)
    a2c_reward = np.zeros(NUM_OF_GAMES)
    game_finished = np.zeros(NUM_OF_GAMES)
    for i in range(NUM_OF_GAMES):
        _, a2c_reward[i], game_finished[i], _  = envs[i].step(a2c_actions[i])
        if game_finished[i] == True and dones[i] == False:
            dones[i] = True
            final_rewards[i] = a2c_reward[i]
    print("Both players have done a move.")

win_as_second_player = np.count_nonzero(final_rewards == 1)/len(dones)
draw_as_second_player = np.count_nonzero(final_rewards == 0)/len(dones)

print("win rate as second player: ", win_as_second_player)
print("draw rate as second player: ", draw_as_second_player)
# Out:
# Models loaded from memory
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Models loaded from memory
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 0  out of  500
# Both players have done a move.
# 2  out of  500
# Both players have done a move.
# 3  out of  500
# Both players have done a move.
# 6  out of  500
# Both players have done a move.
# 11  out of  500
# Both players have done a move.
# 33  out of  500
# Both players have done a move.
# 55  out of  500
# Both players have done a move.
# 88  out of  500
# Both players have done a move.
# 146  out of  500
# Both players have done a move.
# 193  out of  500
# Both players have done a move.
# 263  out of  500
# Both players have done a move.
# 330  out of  500
# Both players have done a move.
# 388  out of  500
# Both players have done a move.
# 436  out of  500
# Both players have done a move.
# 462  out of  500
# Both players have done a move.
# 474  out of  500
# Both players have done a move.
# 486  out of  500
# Both players have done a move.
# 493  out of  500
# Both players have done a move.
# 498  out of  500
# Both players have done a move.
# win rate as second player:  0.366
# draw rate as second player:  0.04

# %%
total_win = (win_as_first_player+win_as_second_player)/2
total_draw = (draw_as_first_player+draw_as_second_player)/2
print("Total win rate: ", total_win)
print("Total draw rate: ", total_draw)
print("Total loss: ", 1-total_draw-total_win)
# Out:
# Total win rate:  0.419
# Total draw rate:  0.043
# Total loss:  0.538
